# %% [markdown]
# # Transaction Categorization Assignment
#
# ### Background
#
# Quickbooks Online (QBO) is a web-based service which provides financial management and tax preparation services for US and global small business owners. Quickbooks primary service allows users to track bank, credit card, investment, and loan balances and transactions through a single user interface, as well as manage billings, payments, payroll, reports and taxes.
#
# ### The Problem
#
# If a user can assign all of his or her bank transactions to the right tax categories, tax preparation will be a breeze. Small business owners could maximize their tax deductions and minimize audit risks if they do the transaction categorization correctly. The goal is to automate the categorization work to save user’s time. Can you predict the tax category given the bank transaction?
#
#
# # Guidelines
#
# The end goal is to build a model that predicts the tax category given the bank transaction detail.
#
# You have one hour and a half to explore the data and build a simple prediction model, or at least present a roadmap for developing a model at a later stage. You can choose a programming environment that you are familiar with, such as RStudio, Jupyter Notebook. You can use external resources (e.g. public libraries and packages, Google and StackOverFlow) but not help from other people.
#
# After that, we would like you to present your code and discuss it with you. We are much more interested in learning about your thinking process, how you make decisions and why. The performance of the model is of lesser importance.
#
# ### Data
#
#
# The CSV file categorization_data.csv contains transactions of QBO users. It is based on anonymized real data on real users (with some random noise added to preserve privacy). This is being shared privately with you. Please delete the file and notebooks after the interview and do not share this data with anyone.
#
# Here is a small sample of the fields following a short description:
#
#
# <table>
#   <tr>
#    <td><strong>company_id</strong>
#    </td>
#    <td><strong>txn_id</strong>
#    </td>
#    <td><strong>txn_date</strong>
#    </td>
#    <td><strong>txn_desc</strong>
#    </td>
#    <td><strong>txn_amount</strong>
#    </td>
#    <td><strong>personal_cat_name</strong>
#    </td>
#    <td><strong>tax_category</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>123145758185877
#    </td>
#    <td>11988
#    </td>
#    <td>2018-10-26T12:00:00.000Z
#    </td>
#    <td>paragon physical therapy
#    </td>
#    <td>-1.52E+10
#    </td>
#    <td>Health & Care
#    </td>
#    <td><strong>Payroll Expenses</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>123145857618364
#    </td>
#    <td>211574
#    </td>
#    <td>2017-06-26T07:00:00.000Z
#    </td>
#    <td>zyto
#    </td>
#    <td>-4.00E+08
#    </td>
#    <td>Business Services
#    </td>
#    <td><strong>Office/General Administrative Expenses</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>193514600505359
#    </td>
#    <td>805405
#    </td>
#    <td>2018-07-09T07:00:00.000Z
#    </td>
#    <td>shell
#    </td>
#    <td>-2.72E+08
#    </td>
#    <td>Bills
#    </td>
#    <td><strong>Auto</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>1046221400
#    </td>
#    <td>47470
#    </td>
#    <td>2018-03-01T20:00:00.000Z
#    </td>
#    <td>online ach orozco
#    </td>
#    <td>-6.33E+09
#    </td>
#    <td>Transfer
#    </td>
#    <td><strong>Payroll Expenses</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>123145723014849
#    </td>
#    <td>548192
#    </td>
#    <td>2018-05-17T19:00:00.000Z
#    </td>
#    <td>ace hotel portland llc
#    </td>
#    <td>-4.66E+09
#    </td>
#    <td>Entertainment
#    </td>
#    <td><strong>Travel</strong>
#    </td>
#   </tr>
# </table>
#
#
#
# <p></p>
#
#
# `company_id`:  a unique identifier for each company
#
# `txn_id`: an id for each data entry event.
#
# `txn_date`: date of the transaction
#
# `txn_desc`: description of the transaction with merchant names
#
# `txn_amount`: amount of the transaction
#
# `personal_cat_name`: a personal category description predicted for each transaction. This field is derived from an upstream model built for our personal finance management product line. More details could be found in the appendix.
#
# `tax_category`: <strong>This is the target of this task</strong>. Each value of tax categories corresponds to a tax form line item.
#
# <p></p>
#
# # Appendix
#
# <p></p>
#
#   ###  List of tax categories
#
# <table>
#   <tr>
#    <td>
#     <strong>tax_category</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Payroll Expenses
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Entertainment Meals
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Office/General Administrative Expenses
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Bank Charges
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Travel
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Legal & Professional Fees
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Repair & Maintenance
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Utilities
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Auto
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Supplies & Materials
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Dues & subscriptions
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Insurance
#    </td>
#   </tr>
# </table>
#
#
#
# ### List of personal categories
#
#
# <table>
#   <tr>
#    <td>
#     <strong>personal_cat_name</strong>
#    </td>
#    <td>
#     <strong>personal_cat_name</strong>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Cash & ATM
#    </td>
#    <td>
#     Education
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Uncategorized
#    </td>
#    <td>
#     Entertainment
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Check
#    </td>
#    <td>
#     Tax
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Business Services
#    </td>
#    <td>
#     Bills
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Transfer
#    </td>
#    <td>
#     Clothing
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Books
#    </td>
#    <td>
#     Kids
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Food
#    </td>
#    <td>
#     Electronics & Software
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Loan
#    </td>
#    <td>
#     Sporting Goods
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Fees
#    </td>
#    <td>
#     Computer Software
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Health & Care
#    </td>
#    <td>
#     Transfer for Cash Spending
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Income
#    </td>
#    <td>
#     Interest Income
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Home
#    </td>
#    <td>
#     Reimbursement
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Credit Card Payment
#    </td>
#    <td>
#     Insurance
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Gift
#    </td>
#    <td>
#
#    </td>
#   </tr>
# </table>
#
# <p></p>
#
#
# # Good   Luck ! ! !

# %%
import pandas as pd
df = pd.read_csv("./categorization_data.csv")

# %%
df.head()
# Out:
#         company_id  txn_id                  txn_date          txn_desc  \
# 0       1403407275       0  2017-12-20T20:00:00.000Z    atm withdrawal
# 1        111715112       1  2019-01-29T12:00:00.000Z  changing your mi
# 2        379049486       2  2017-11-20T20:00:00.000Z             check
# 3  123145912028844       3  2019-02-04T12:00:00.000Z             check
# 4        397073921       4  2018-03-30T06:59:59.000Z   payroll marcy l
#
#      txn_amount personal_cat_name      tax_category
# 0 -6.000000e+08        Cash & ATM  Payroll Expenses
# 1 -8.850000e+08     Uncategorized  Payroll Expenses
# 2 -2.820000e+09             Check  Payroll Expenses
# 3 -1.120000e+10             Check  Payroll Expenses
# 4 -3.881930e+10     Uncategorized  Payroll Expenses

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
#import lightgbm as lgb

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.ensemble import RandomForestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report, roc_auc_score,roc_curve, auc

import xgboost as xgb

import itertools 

# %matplotlib inline

# %%
# in total we have 1 million dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998398 entries, 0 to 998397
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   company_id         998398 non-null  int64
#  1   txn_id             998398 non-null  int64
#  2   txn_date           998398 non-null  object
#  3   txn_desc           998396 non-null  object
#  4   txn_amount         998398 non-null  float64
#  5   personal_cat_name  951845 non-null  object
#  6   tax_category       998398 non-null  object
#  7   weekday            998398 non-null  int64
#  8   day_of_month       998398 non-null  int64
#  9   month              998398 non-null  int64
#  10  year               998398 non-null  int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 83.8+ MB

# %%
df.describe()
# Out:
#          company_id         txn_id    txn_amount        weekday  \
# count  9.983980e+05  998398.000000  9.983980e+05  998398.000000
# mean   8.753140e+13  499198.500000 -3.439901e+09       2.207906
# std    7.783577e+13  288212.821367  4.445605e+10       1.742093
# min    5.122586e+07       0.000000 -1.767126e+13       0.000000
# 25%    1.214394e+09  249599.250000 -1.600000e+09       1.000000
# 50%    1.231457e+14  499198.500000 -4.762000e+08       2.000000
# 75%    1.231459e+14  748797.750000 -1.594000e+08       4.000000
# max    1.935147e+14  998397.000000  2.500000e+12       6.000000
#
#         day_of_month          month           year
# count  998398.000000  998398.000000  998398.000000
# mean       15.392707       6.530474    2017.979110
# std         8.890463       3.511470       0.668209
# min         1.000000       1.000000    2016.000000
# 25%         8.000000       3.000000    2018.000000
# 50%        15.000000       7.000000    2018.000000
# 75%        23.000000      10.000000    2018.000000
# max        31.000000      12.000000    2019.000000

# %%
df.isnull().sum()
# there are missing data for personal_cat_name, maybe the upstream model is uncertain about the predictions
# there is also Uncategorized data, lets fill the missing value to be Uncategorized
# Out:
# company_id               0
# txn_id                   0
# txn_date                 0
# txn_desc                 2
# txn_amount               0
# personal_cat_name    46553
# tax_category             0
# weekday                  0
# day_of_month             0
# month                    0
# year                     0
# dtype: int64

# %%
df['personal_cat_name0'] = df['personal_cat_name'].fillna('Uncategorized')

# %%
df.isnull().sum() # now missing data is filled in a new column personal_cat_name0
# Out:
# company_id                0
# txn_id                    0
# txn_date                  0
# txn_desc                  2
# txn_amount                0
# personal_cat_name     46553
# tax_category              0
# weekday                   0
# day_of_month              0
# month                     0
# year                      0
# personal_cat_name0        0
# dtype: int64

# %%
sns.countplot(df['tax_category'])
# class imbalance exist but not sever

# %%
# get time features
df['weekday'] = pd.to_datetime(df['txn_date']).dt.weekday
df['day_of_month'] = pd.to_datetime(df['txn_date']).dt.day
df['month'] = pd.to_datetime(df['txn_date']).dt.month
df['year'] = pd.to_datetime(df['txn_date']).dt.year
#df['hour_of_day'] = train_data.pickup_datetime.dt.hour

# %%
df
# Out:
#              company_id  txn_id                  txn_date  \
# 0            1403407275       0  2017-12-20T20:00:00.000Z
# 1             111715112       1  2019-01-29T12:00:00.000Z
# 2             379049486       2  2017-11-20T20:00:00.000Z
# 3       123145912028844       3  2019-02-04T12:00:00.000Z
# 4             397073921       4  2018-03-30T06:59:59.000Z
# ...                 ...     ...                       ...
# 998393  123145753826632  998393  2018-12-13T12:00:00.000Z
# 998394  123145818674854  998394  2018-11-07T12:00:00.000Z
# 998395        401773356  998395  2018-12-04T20:00:00.000Z
# 998396  123145839218797  998396  2018-08-17T19:00:00.000Z
# 998397  123145765606457  998397  2018-03-22T19:00:00.000Z
#
#                              txn_desc    txn_amount  personal_cat_name  \
# 0                      atm withdrawal -6.000000e+08         Cash & ATM
# 1                    changing your mi -8.850000e+08      Uncategorized
# 2                               check -2.820000e+09              Check
# 3                               check -1.120000e+10              Check
# 4                     payroll marcy l -3.881930e+10      Uncategorized
# ...                               ...           ...                ...
# 998393              horizon homes llc -1.191640e+10               Home
# 998394          pharm d solutions llc -8.479000e+08  Business Services
# 998395  auto owners insurance company -8.529600e+09  Business Services
# 998396  auto owners insurance company -3.291000e+08      Health & Care
# 998397             more insurance llc -5.324200e+09  Business Services
#
#             tax_category  weekday  day_of_month  month  year
# 0       Payroll Expenses        2            20     12  2017
# 1       Payroll Expenses        1            29      1  2019
# 2       Payroll Expenses        0            20     11  2017
# 3       Payroll Expenses        0             4      2  2019
# 4       Payroll Expenses        4            30      3  2018
# ...                  ...      ...           ...    ...   ...
# 998393         Insurance        3            13     12  2018
# 998394         Insurance        2             7     11  2018
# 998395         Insurance        1             4     12  2018
# 998396         Insurance        4            17      8  2018
# 998397         Insurance        3            22      3  2018
#
# [998398 rows x 11 columns]

# %%
# Is time really related to the predictions?
### countplot
fig, ((a,b),(c,d)) = plt.subplots(2,2,figsize=(15,20))
plt.xticks(rotation=45)
sns.countplot(df['weekday'],hue=df['tax_category'],ax=a)
sns.countplot(df['month'],hue=df['tax_category'],ax=b)
sns.countplot(df['day_of_month'],hue=df['tax_category'],ax=c)
sns.countplot(df['year'],hue=df['tax_category'],ax=d)


# on weekend people has less office related activities
# weekdays, especially Monday, meals and office expense is higher
# In general office expense is the highest out of all
# some variantion across months are obsevered
# insurance are mostly stable over the months
# year observation is observed but may not be useful for future prediction

# %%
# lets see how the tax amount related to the output
g = sns.FacetGrid(df,  col="tax_category", row="txn_amount", )

# %%
len(df.company_id.unique())
# Out:
# 107289

# %%
len(df.txn_desc.unique()) #  lots of descriptions, need to dig into it, but now drop.
# Out:
# 219560

# %%
len(df.personal_cat_name.unique()) #
# Out:
# 28

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['personal_cat_name'],hue=df['tax_category'])

# these features are related

# %%
# Let's now build a baseline model!

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
df['tax_category'] = le.fit_transform(df['tax_category'])

# %%
df['personal_cat_name0'] = le.fit_transform(df['personal_cat_name0'].apply(str))

# %%
# normalize the text amount 
sns.distplot(df['txn_amount'], bins=100) 
plt.show()
# there are some tax amount that are extremely large
# need to understand why is that? is this realizetic? Maybe.
# standarization can improve performance

# %%
df.describe()
# Out:
#          company_id         txn_id    txn_amount  personal_cat_name  \
# count  9.983980e+05  998398.000000  9.983980e+05      998398.000000
# mean   8.753140e+13  499198.500000 -3.439901e+09           9.666492
# std    7.783577e+13  288212.821367  4.445605e+10           8.878020
# min    5.122586e+07       0.000000 -1.767126e+13           0.000000
# 25%    1.214394e+09  249599.250000 -1.600000e+09           2.000000
# 50%    1.231457e+14  499198.500000 -4.762000e+08          10.000000
# 75%    1.231459e+14  748797.750000 -1.594000e+08          14.000000
# max    1.935147e+14  998397.000000  2.500000e+12          27.000000
#
#         tax_category        weekday   day_of_month          month  \
# count  998398.000000  998398.000000  998398.000000  998398.000000
# mean        5.379772       2.207906      15.392707       6.530474
# std         3.398547       1.742093       8.890463       3.511470
# min         0.000000       0.000000       1.000000       1.000000
# 25%         3.000000       1.000000       8.000000       3.000000
# 50%         6.000000       2.000000      15.000000       7.000000
# 75%         8.000000       4.000000      23.000000      10.000000
# max        11.000000       6.000000      31.000000      12.000000
#
#                 year  personal_cat_name0
# count  998398.000000       998398.000000
# mean     2017.979110            9.619864
# std         0.668209            8.789042
# min      2016.000000            0.000000
# 25%      2018.000000            2.000000
# 50%      2018.000000           10.000000
# 75%      2018.000000           14.000000
# max      2019.000000           26.000000

# %%
df
# Out:
#              company_id  txn_id                  txn_date  \
# 0            1403407275       0  2017-12-20T20:00:00.000Z
# 1             111715112       1  2019-01-29T12:00:00.000Z
# 2             379049486       2  2017-11-20T20:00:00.000Z
# 3       123145912028844       3  2019-02-04T12:00:00.000Z
# 4             397073921       4  2018-03-30T06:59:59.000Z
# ...                 ...     ...                       ...
# 998393  123145753826632  998393  2018-12-13T12:00:00.000Z
# 998394  123145818674854  998394  2018-11-07T12:00:00.000Z
# 998395        401773356  998395  2018-12-04T20:00:00.000Z
# 998396  123145839218797  998396  2018-08-17T19:00:00.000Z
# 998397  123145765606457  998397  2018-03-22T19:00:00.000Z
#
#                              txn_desc    txn_amount  personal_cat_name  \
# 0                      atm withdrawal -6.000000e+08                  3
# 1                    changing your mi -8.850000e+08                 26
# 2                               check -2.820000e+09                  4
# 3                               check -1.120000e+10                  4
# 4                     payroll marcy l -3.881930e+10                 26
# ...                               ...           ...                ...
# 998393              horizon homes llc -1.191640e+10                 15
# 998394          pharm d solutions llc -8.479000e+08                  2
# 998395  auto owners insurance company -8.529600e+09                  2
# 998396  auto owners insurance company -3.291000e+08                 14
# 998397             more insurance llc -5.324200e+09                  2
#
#         tax_category  weekday  day_of_month  month  year  personal_cat_name0
# 0                  7        2            20     12  2017                   3
# 1                  7        1            29      1  2019                  26
# 2                  7        0            20     11  2017                   4
# 3                  7        0             4      2  2019                   4
# 4                  7        4            30      3  2018                  26
# ...              ...      ...           ...    ...   ...                 ...
# 998393             4        3            13     12  2018                  15
# 998394             4        2             7     11  2018                   2
# 998395             4        1             4     12  2018                   2
# 998396             4        4            17      8  2018                  14
# 998397             4        3            22      3  2018                   2
#
# [998398 rows x 12 columns]

# %%
features = ['personal_cat_name0', 'weekday', 'day_of_month','month']

# %%
X = df[features]

# %%
y = df['tax_category']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998398 entries, 0 to 998397
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   personal_cat_name0  998398 non-null  int64
#  1   weekday             998398 non-null  int64
#  2   day_of_month        998398 non-null  int64
#  3   month               998398 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=123, shuffle=True)

# %%
random_forest = RandomForestClassifier(n_estimators=100,max_features=4)
random_forest.fit(X_train, y_train)
predictions = random_forest.predict(X_test)
print("Accuracy: %s%%" % (100*accuracy_score(y_test, predictions)))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# Accuracy: 47.21955128205128%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-22ff688d858c> in <module>
#       3 predictions = random_forest.predict(X_test)
#       4 print("Accuracy: %s%%" % (100*accuracy_score(y_test, predictions)))
# ----> 5 print(confusion_matrix(Y_validation, predictions))
#       6 print(classification_report(Y_validation, predictions))
#
# NameError: name 'Y_validation' is not defined

# %%
print("Accuracy: %s%%" % (100*accuracy_score(y_test, predictions)))
print(confusion_matrix(y_test, predictions))
# Out:
# Accuracy: 47.21955128205128%
# [[14006  1571    12  1193    60    15  1469   669    17    57  2778   189]
#  [  363 10999    28   319   115    38  2445   388    16   107  1501   223]
#  [  295   199   171   212   187    24  3596   365    12    80  2001   173]
#  [  593   128    42 19570   167    22  1907   191    22   100  2625   161]
#  [ 1280   107     6    72  1074    11  2091   760     9    68   602   216]
#  [   62   230    29   126   144    32  2302  1684    16    56  1266   144]
#  [ 3082  1415   336  3283   526    80 27534  3143   111   647  5482  1394]
#  [  111   414    26   330   346    59  4240  5699    39    90  1403   163]
#  [  238   122    15   136    44    27  1174  1721   195   912  1206   975]
#  [  444   270    61  1470   310    28 10018  1406   306  1653  2215  1270]
#  [ 2763  1597    40  1167    58    14  1876   393    19    81  9560   141]
#  [ 4651   403    10    72    34    17   965  1278    25    84   660  3795]]

# %%
# get feature importance from random forest
importances = random_forest.feature_importances_
sorted_idx = importances.argsort()
feature_names = features[:13]
feature_names0 = [feature_names[i] for i in sorted_idx]

y_ticks = np.arange(0, len(sorted_idx))
fig, ax = plt.subplots()
ax.barh(y_ticks, importances[sorted_idx])
ax.set_yticklabels(feature_names0)
ax.set_yticks(y_ticks)
ax.set_title("Random Forest Feature Importances (MDI)")
fig.tight_layout()
plt.show()

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.64      0.56     22036
#            1       0.63      0.66      0.65     16542
#            2       0.22      0.02      0.04      7315
#            3       0.70      0.77      0.73     25528
#            4       0.35      0.17      0.23      6296
#            5       0.09      0.01      0.01      6091
#            6       0.46      0.59      0.52     47033
#            7       0.32      0.44      0.37     12920
#            8       0.25      0.03      0.05      6765
#            9       0.42      0.08      0.14     19451
#           10       0.31      0.54      0.39     17709
#           11       0.43      0.32      0.36     11994
#
#     accuracy                           0.47    199680
#    macro avg       0.39      0.36      0.34    199680
# weighted avg       0.45      0.47      0.44    199680

# %%
features1 = [ 'txn_amount', 'personal_cat_name0', 'weekday', 'day_of_month','month']

# %%
X = df[features1]

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
predictions = random_forest.predict(X_test)
print("Accuracy: %s%%" % (100*accuracy_score(y_test, predictions)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 47.23908253205128%
# [[13999  1563    13  1197    61    19  1487   669    16    56  2762   194]
#  [  367 11004    22   309   113    37  2474   394    14   102  1488   218]
#  [  297   201   159   215   185    22  3629   362    12    78  1983   172]
#  [  588   120    49 19578   171    19  1918   196    22   111  2592   164]
#  [ 1276   111     4    74  1061    11  2094   774    11    69   593   218]
#  [   65   237    24   128   138    32  2322  1690    15    50  1250   140]
#  [ 3080  1430   301  3278   525    77 27659  3146   101   618  5421  1397]
#  [  113   417    26   327   348    43  4266  5707    42    85  1377   169]
#  [  237   123    12   135    45    23  1181  1737   195   905  1191   981]
#  [  438   267    60  1476   306    18 10059  1412   308  1640  2192  1275]
#  [ 2762  1594    50  1162    57    12  1933   398    19    78  9497   147]
#  [ 4647   405     9    69    39    10   980  1289    28    74   648  3796]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.64      0.56     22036
#            1       0.63      0.67      0.65     16542
#            2       0.22      0.02      0.04      7315
#            3       0.70      0.77      0.73     25528
#            4       0.35      0.17      0.23      6296
#            5       0.10      0.01      0.01      6091
#            6       0.46      0.59      0.52     47033
#            7       0.32      0.44      0.37     12920
#            8       0.25      0.03      0.05      6765
#            9       0.42      0.08      0.14     19451
#           10       0.31      0.54      0.39     17709
#           11       0.43      0.32      0.36     11994
#
#     accuracy                           0.47    199680
#    macro avg       0.39      0.35      0.34    199680
# weighted avg       0.45      0.47      0.44    199680

# %%
# Insight:
# the personal Cat name from upstream is indeed helpful when predicting the target
# todos:
# can dig into the uncategorized dataset to futher label it, ( key words exaction from txn_desc )
